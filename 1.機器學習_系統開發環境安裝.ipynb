# %% [markdown]
# # 機器學習實務_系統開發環境安裝
# ## 實作內容:實作學習 Anaconda Python+opencv+Dlib套件安裝

# %% [markdown]
# # A.實作練習開發環境安裝設定  Installation Requirements
# ## 1.Anaconda
# ## 安裝 anaconda , python
# ## Anaconda
# <li>（ https://www.anaconda.com/download/#windows ）
#
# <li>Anaconda 是一个开源的 Python 发行版本，相比于原生的 Python 集成了很多常用的库，安装和卸载管理库都要方便
#     <br>安装完成之后,可在anaconda選單下找到 Anaconda Promopt,進入中終端操作畫面(Anaconda python )
#    ![image.png](attachment:image.png)

# %% [markdown]
# ## 2.安裝套件,在 Anaconda 中,可用 conda  or  pip  ==> python套件安裝管理程式
# <li>Conda是Anaconda 套件管理系統,在 Anaconda 中可透過 conda or pip 來安裝套件
#     <br>==>安裝package：
#               <br>   conda install packageName  or pip install packagename
#               <br>將packageName換成你想要的任何套件像是：
# <br>ex:==>conda install pandas
#  ![image.png](attachment:image.png)

# %% [markdown]
# ## 3.用pip 安裝  package 過程中,可能會出現如下畫面,請依指令更新pip
# <br>
# ![image.png](attachment:image.png)
# <br>
# ==>python -m pip install --upgrade pip

# %% [markdown]
# ## 4.開始 Installation Options:
# # <li>dlib 套件:至少要19.7版
# ## Dlib 简介:Dlib 是一个机器学习的开源工具包（ 官网：http://dlib.net/ ），用于机器人，嵌入式设备，移动电话和大型高性能计算环境等等
# ## Dlib 檔案要下载回來：
#     https://github.com/davisking/dlib
#     https://github.com/coneypo
#     https://github.com/coneypo/Dlib_install/blob/master/dlib-19.7.0-cp36-cp36m-win_amd64.whl
# <br> ==>cp36 是for python 3.6
# <li>Binary Classification
# <li>Face Detector/Face Recognition
# <li>Find Candidate Object Locations
# <li>Global Optimization
# <li>Linear Assignment Problems
# <li>Sequence Segmenter
# <li>Structural Support Vector Machines
# <li>SVM-Rank
# <li>Train Object Detector
# <li>Train Shape Predictor
# <li>Video Object Tracking
# <br>
#  在 Anaconda Prompt 中先利用  'cd' 命令定位到 Dlib 的 whl 文件 所在路径，'dir' 命令可以查看当前路径下的文件；
# 　　然后 pip 安装 Dlib 的 whl 文件：
# ## ==>pip install dlib-19.7.0-cp36-cp36m-win_amd64.whl
# ## or
# ## ==>pip install dlib-19.8.1-cp36-cp36m-win_amd64.whl

# %% [markdown]
# ## 安裝 Dlib 可能會出現如下畫面
# ![image.png](attachment:image.png)
# <br>請依指令安裝 msgpack
# <br>==>pip install msgpack

# %% [markdown]
# # <li>opencv 套件
# ## ==>pip install opencv3
#     or
# ## ==> pip install opencv-python

# %% [markdown]
# ## <li> 測試 opencv 是否安裝成功

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.7.0

# %% [markdown]
# ### Scikit-learn介紹:機器學習套件 for python
# ### https://scikit-learn.org/stable/
# ### Scikit-learn簡稱SKlearn(由於在python使用時為import sklearn)，SKlearn已內建在一開始安裝的Anaconda套件中，可以直接使用，套件中包含許多知名的Machine learning演算法.
# ### Sklearn在官網把他提供的功能分為六大塊，分別是監督式學習的分類(Classification)以及回歸(Regression)演算法、非監督式的分群演算法(Clustering)、還有降低維度(Dimensionality reduction)、模型選擇(Model selection)以及資料的前處理(Preprocess)。
# ![image.png](attachment:image.png)

# %% [markdown]
# ### <li> Choosing the right estimator
#
# ### 解决机器学习问题最困难的部分通常是为要解決的問題工作找到正确的估算器( estimator):演算法==>預測模型 計算模型)。
# ### 不同的估计器适合于不同类型的数据和不同的问题。
# ### Sklearn 提供流程图,幫用户提供一些关于如何处理机器学习问题該採用/有关哪些估算器來尝试。
# https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <li> 測試  sklearn 套件是否有安裝成功

# %%
from sklearn import neighbors
